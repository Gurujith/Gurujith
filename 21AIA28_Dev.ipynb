# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurujith/Gurujith/blob/main/21AIA28_Dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Passengers.csv')

# %%
df
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2014  2014      5       14492     RDU       36      11032
# 1       06/01/2007  2007      6       13204     MCO       33      16085
# 2       12/01/2005  2005     12       11433     DTW       43      10411
# 3       04/01/2003  2003      4       13487     MSP       63      16304
# 4       12/01/2005  2005     12       12016     GUM        5      11138
# ...            ...   ...    ...         ...     ...      ...        ...
# 121920  04/01/2017  2017      4       11042     CLE       44      11628
# 121921  04/01/2017  2017      4       11042     CLE       44      14293
# 121922  04/01/2017  2017      4       11042     CLE       44      16271
# 121923  04/01/2017  2017      4       11042     CLE       44      16271
# 121924  04/01/2017  2017      4       11057     CLT       36         16
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121925 entries, 0 to 121924
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   data_dte      121925 non-null  object
#  1   Year          121925 non-null  int64
#  2   Month         121925 non-null  int64
#  3   usg_apt_id    121925 non-null  int64
#  4   usg_apt       121925 non-null  object
#  5   usg_wac       121925 non-null  int64
#  6   fg_apt_id     121925 non-null  int64
#  7   fg_apt        121924 non-null  object
#  8   fg_wac        121924 non-null  float64
#  9   airlineid     121924 non-null  float64
#  10  carrier       120950 non-null  object
#  11  carriergroup  121924 non-null  float64
#  12  type          121924 non-null  object
#  13  Scheduled     121924 non-null  float64
#  14  Charter       121924 non-null  float64
#  15  Total         121924 non-null  float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 14.9+ MB

# %%
df.head(10)
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1  06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3  04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12/01/2005  2005     12       12016     GUM        5      11138    CRK
# 5  03/01/2007  2007      3       14843     SJU        3      15084    SXM
# 6  03/01/2001  2001      3       14986     SRQ       33      13252    MEX
# 7  04/01/2007  2007      4       14027     PBI       33      11760    FRA
# 8  09/01/2005  2005      9       10559     BFI       93      15999    YAZ
# 9  08/01/2004  2004      8       10821     BWI       35      10150    ACC
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0   148.0    19534.0      AM           0.0  Passengers        0.0    315.0
# ...

# %%
df.shape
# Out:
# (121925, 16)

# %%
df.describe()
# Out:
#                 Year          Month     usg_apt_id        usg_wac  \
# count  121925.000000  121925.000000  121925.000000  121925.000000
# mean     2002.690925       6.154677   12865.242206      42.684019
# std         8.062126       3.527672    3525.720061      25.679637
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1996.000000       3.000000   11433.000000      22.000000
# 50%      2002.000000       6.000000   12892.000000      33.000000
# 75%      2010.000000       9.000000   13930.000000      64.000000
# max      2019.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  Scheduled  \
# count  121925.000000  121924.000000  121924.000000  121924.000000   121924.0
# mean    13565.604823     435.725977   20285.694228       0.611963        0.0
# std      2029.455761     306.433261     508.004382       0.487305        0.0
# ...

# %%
df.isnull()
# Out:
#         data_dte   Year  Month  usg_apt_id  usg_apt  usg_wac  fg_apt_id  \
# 0          False  False  False       False    False    False      False
# 1          False  False  False       False    False    False      False
# 2          False  False  False       False    False    False      False
# 3          False  False  False       False    False    False      False
# 4          False  False  False       False    False    False      False
# ...          ...    ...    ...         ...      ...      ...        ...
# 121920     False  False  False       False    False    False      False
# 121921     False  False  False       False    False    False      False
# 121922     False  False  False       False    False    False      False
# 121923     False  False  False       False    False    False      False
# 121924     False  False  False       False    False    False      False
#
#         fg_apt  fg_wac  airlineid  carrier  carriergroup   type  Scheduled  \
# ...

# %%
df.columns
# Out:
# Index(['data_dte', 'Year', 'Month', 'usg_apt_id', 'usg_apt', 'usg_wac',
#        'fg_apt_id', 'fg_apt', 'fg_wac', 'airlineid', 'carrier', 'carriergroup',
#        'type', 'Scheduled', 'Charter', 'Total'],
#       dtype='object')

# %%
df.nunique()
# Out:
# data_dte         335
# Year              30
# Month             12
# usg_apt_id       733
# usg_apt          738
# usg_wac           54
# fg_apt_id       1071
# fg_apt          1072
# fg_wac           195
# airlineid        350
# carrier          373
# carriergroup       2
# type               1
# Scheduled          1
# Charter         8219
# Total           8219
# dtype: int64

# %%
df['airlineid'].unique
# Out:
# <bound method Series.unique of 0         19534.0
# 1         20364.0
# 2         20344.0
# 3         20204.0
# 4         20312.0
#            ...
# 121920    21814.0
# 121921    20207.0
# 121922    19790.0
# 121923    21437.0
# 121924        NaN
# Name: airlineid, Length: 121925, dtype: float64>

# %%
df.tail()
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 121920  04/01/2017  2017      4       11042     CLE       44      11628
# 121921  04/01/2017  2017      4       11042     CLE       44      14293
# 121922  04/01/2017  2017      4       11042     CLE       44      16271
# 121923  04/01/2017  2017      4       11042     CLE       44      16271
# 121924  04/01/2017  2017      4       11057     CLT       36         16
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# 121920    FAB   493.0    21814.0     2UQ           0.0  Passengers        0.0
# 121921    PUJ   224.0    20207.0      XP           1.0  Passengers        0.0
# 121922    YYZ   936.0    19790.0      DL           1.0  Passengers        0.0
# 121923    YYZ   936.0    21437.0     13Q           0.0  Passengers        0.0
# 121924    NaN     NaN        NaN     NaN           NaN         NaN        NaN
#
#         Charter   Total
# 121920      4.0     4.0
# ...

# %%
df.isnull().sum()
# Out:
# data_dte          0
# Year              0
# Month             0
# usg_apt_id        0
# usg_apt           0
# usg_wac           0
# fg_apt_id         0
# fg_apt            1
# fg_wac            1
# airlineid         1
# carrier         975
# carriergroup      1
# type              1
# Scheduled         1
# Charter           1
# Total             1
# dtype: int64

# %%
df.drop(['type'],axis=1)
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2014  2014      5       14492     RDU       36      11032
# 1       06/01/2007  2007      6       13204     MCO       33      16085
# 2       12/01/2005  2005     12       11433     DTW       43      10411
# 3       04/01/2003  2003      4       13487     MSP       63      16304
# 4       12/01/2005  2005     12       12016     GUM        5      11138
# ...            ...   ...    ...         ...     ...      ...        ...
# 121920  04/01/2017  2017      4       11042     CLE       44      11628
# 121921  04/01/2017  2017      4       11042     CLE       44      14293
# 121922  04/01/2017  2017      4       11042     CLE       44      16271
# 121923  04/01/2017  2017      4       11042     CLE       44      16271
# 121924  04/01/2017  2017      4       11057     CLT       36         16
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup  Scheduled  Charter  \
# ...

# %%
plt.plot(df.Charter)

# %%
plt.scatter(df.Charter,df.Total,color='green')
df
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2014  2014      5       14492     RDU       36      11032
# 1       06/01/2007  2007      6       13204     MCO       33      16085
# 2       12/01/2005  2005     12       11433     DTW       43      10411
# 3       04/01/2003  2003      4       13487     MSP       63      16304
# 4       12/01/2005  2005     12       12016     GUM        5      11138
# ...            ...   ...    ...         ...     ...      ...        ...
# 121920  04/01/2017  2017      4       11042     CLE       44      11628
# 121921  04/01/2017  2017      4       11042     CLE       44      14293
# 121922  04/01/2017  2017      4       11042     CLE       44      16271
# 121923  04/01/2017  2017      4       11042     CLE       44      16271
# 121924  04/01/2017  2017      4       11057     CLT       36         16
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# ...

# %%
x=df.fg_apt_id	
y=df.usg_wac
z=df.fg_wac
plt.scatter(x,z)
plt.scatter(y,z)
plt.scatter(x,y)

# %%
plt.hist(df['Year'])
plt.show()

# %%
plt.plot(df.usg_wac,color='r') 
plt.plot(df.fg_wac,color='g')
plt.plot(df.Month,color='b')
plt.show()

# %%
plt.plot(df.fg_wac,marker='o',color='b')
plt.show()

# %%
plt.plot(df.Month, linestyle = 'dotted')
plt.show()

# %%
x=df.Charter
y=df.Total
plt.scatter(x,y,color='y')
plt.grid()
plt.show()

# %%
plt.fill_between(df.Charter,df.Total,color='red')
plt.show()
